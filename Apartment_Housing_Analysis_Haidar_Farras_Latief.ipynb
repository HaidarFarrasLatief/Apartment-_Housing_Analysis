# %% [markdown]
# # Link untuk dashboard Tableau:

# %% [markdown]
# https://public.tableau.com/app/profile/haidar.farras/viz/Milestone_Haidar_Farras_Latief/Dashboard1?publish=yes

# %% [markdown]
# # 1. Perkenalan

# %% [markdown]
# ## 1.1 Identitas

# %% [markdown]
# Haidar Farras Latief - 001

# %% [markdown]
# ## 1.2 General Instructions

# %% [markdown]
# 1. Pilihlah satu topik bebas dan buat problem statement terlebih dahulu menggunakan metode SMART.
#
# 2. Dataset dibebaskan dari sumber manapun (BigQuery, Kaggle, BPS, dll.) dan berformat apapun (csv, excel, json, sql query, dll.) NOTE: Wajib mencantumkan sumber referensi data pada bagian Data Loading.
#
# 3. Sebelum menentukan tabel, kolom, atau hal lain dalam dataset mana yang akan dijadikan analisis dan visualisasi data, lakukan identifikasi dan penjabaran masalah supaya dapat memudahkan kamu dalam melakukan analisis. Kamu bisa menggunakan metode apapun seperti analisis SWOT, Fish bone diagram, 5W+1H, dsb.
#
# - Contoh:
#
# - Problem Statement: Mengetahui Preferensi dan Perilaku Konsumsi Makanan di Area Urban di Indonesia dalam kurun waktu tahun 2021
#
# - Penjabaran masalah dengan metode 5W+1H:
#
#     - Kota mana dengan rata-rata % pengeluaran makan paling besar?
#     - Bagaimana perilaku pemilihan makanan berdasarkan harga terhadap social class masyarakat?
#     - Apakah tingkat pendidikan sarjana memiliki preferensi memilih makanan-makanan yang sehat?
#     - Apakah warga DKI Jakarta masih mengonsumsi makanan tradisional?
#     - Usia berapa saja yang masih mengonsumsi makanan tradisional?
#     dsb.
# - Pertanyaan-pertanyaan/penjabaran masalah di atas dapat dijawab dengan data visualisasi dan analisis statistik.
#
# 4. Setelah melakukan identifikasi dan penjabaran masalah, tentukan metrik/data apa saja yang diperlukan lalu tarik data yang diperlukan dari dataset yang sudah ditentukan menggunakan SQL. Cantumkan semua query yang dibuat untuk menarik semua data yang diperlukan dalam milestone ini.
# 5. Perlu diperhatikan bahwa penjabaran masalah untuk dijawab menggunakan data visualisasi dan analisis statistik HARUS mengikuti kriteria berikut:
# - Minimal terdapat 6 penjabaran masalah dimana 4 penjabaran untuk visualisasi data, 1 penjabaran untuk statistik deskriptif, dan 1 penjabaran untuk statistik inferensial.
# 6. Untuk Data Visualisasi dibebaskan menggunakan tipe visualisasi (batang, garis, dsb) dan library (matplotlib, pyplot, seaborn, dsb) apapun, disesuaikan dengan penjabaran masalahnya. Minimal 4 visualisasi sesuai dengan jumlah minimum penjabaran untuk bagian visualisasi data. WAJIB memberikan insight di tiap visualisasi data.
# 7. Untuk Statistik Deskriptif, pilih minimal salah satu perhitungan/analisis statistik deskriptif seperti central tendency, measure of variance, outlier analysis, distribution, dsb. Sesuaikan dengan penjabaran masalah yang ditentukan.
# 8. Untuk Statistik Inferensial, pilih minimal salah satu perhitungan/analisis statistik inferensial seperti confidence interval, statistical significance, statistical testing, hypothesis testing: one sample, two sample independent, paired test, ANOVA, chi-square, dsb. Sesuaikan dengan penjabaran masalah yang ditentukan.
# 9. Output dari milestone ini adalah dashboard data visualisasi menggunakan Tableau Public atau Google Data Studio dan analisis serta pengolahan data di jupyter notebook.

# %% [markdown]
# ## 1.3 Daftar Isi

# %% [markdown]
# Berikut ini adalah daftar isi file ini:
# ```
# 1. Perkenalan
#     1.1 Identitas
#     1.2 General Instructions
# 2. Identifikasi Masalah
#     2.1 Topik Permasalahan
#     2.2 Problem Statement
#     2.3 Latar Belakang
#     2.4 Penjabaran Masalah
#     2.5 Glossary
#         2.5.1 Glossary Istilah Diluar Kolom Dataset
#         2.5.2 Glossary Istilah Didalam Kolom Dataset
# 3. Data Loading
#     3.1 Mengambil Dataset dari Internet
#     3.2 Impor Pustaka yang dibutuhkan
#     3.3 Menghubungkan Dataset dengan file ini
#     3.4 Eksplorasi data 1
#     3.5 Mempersiapkan Dataframe untuk penjabaran
# 4. Analisis Perhitungan
#     4.1 Eksplorasi Data 2
#     4.2 Analisis Data sesuai Penjabaran
#         4.2.1 Penjabaran 1
#         4.2.2 Penjabaran 2
#         4.2.3 Penjabaran 3
#         4.2.4 Penjabaran 4
#         4.2.5 Penjabaran 5
#         4.2.6 Penjabaran 6
#         4.2.7 Penjabaran 7
#         4.2.8 Penjabaran 8
#         4.2.9 Penjabaran 9
#         4.2.10 Penjabran 10
#         4.2.11 Penjabran 11
# 5. Pengambilan Kesimpulan
#
# ```

# %% [markdown]
# # 2. Identifikasi Masalah

# %% [markdown]
# ## 2.1 Topik Permasalahan
#
# Pada milestone phase 0 ini, saya ingin mengambil topik permasalahan pada:
#
# ```
# Analisis sewa properti tempat tinggal di beberapa kota India
# ```
# Latar belakang yang saya tulis pada poin 2.3 merupakan fiksi, hanya untuk menguji keahlian analisis data yang tersedia.
# Dataset yang saya dapat didapat dari Kaggle, linknya adalah berikut ini:
# https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset

# %% [markdown]
# ## 2.2 Problem Statement
#
# ```
# Menemukan karakteristik ketersediaan sewa apartemen di beberapa kota negara India diantara segmen pasar keluarga inti dan keluarga besar dengan penjabaran dataset serta perhitungan keterkaitan variabel diantara tanggal 2022 april sampai 2022 agustus untuk meningkatkan akurasi produksi jasa yang dihasilkan perusahaan.
# ```

# %% [markdown]
# ## 2.3 Latar Belakang

# %% [markdown]
# Perusahaan ingin membuat produk baru berupa properti tempat tinggal (Rumah/apartemen/flat) yang berada pada India, namun karena perusahaan belum mengetahui segmentasi pasar properti tempat tinggal di India. Maka perusahaan membutuhkan analisis untuk segmentasi pasar dari dataset yang didapat dari aplikasi e-commerce properti tempat tinggal.

# %% [markdown]
# ## 2.4 Penjabaran Masalah

# %% [markdown]
# Penjabaran masalah yang akan saya jabarkan:
#
# ```
# 1. Apa Rata-rata hari upload, biaya sewa, ukuran ruangan, Jumlah kamar mandi ?
#
# 2. Apa Rata-rata hari upload, biaya sewa, ukuran ruangan, Jumlah kamar mandi untuk target konsumen keluarga inti dan keluarga besar ?
#
# 3. Apa grafik perbandingan ketersediaan jumlah kamar mandi pada masing-masing kriteria Tipe Keluarga ?
#
# 4. Seberapa beda harga sewa tiap bulan pada kategori area untuk keluarga inti dan keluarga besar ?
#
# 5. Kota apa dengan rata-rata harga termurah pada keluarga inti dan keluarga besar ?
#
# 6. Apakah ada hubungan Area Type dengan Point of Contact ?
#
# 7. Apakah ada hubungan Furnishing Status dan Tipe Keluarga ?
#
# 8. Apakah ada hubungan Furnishing Status dan Tenant Preferred
#
# 9. Perusahaan ingin membuat properti rumah tinggal untuk konsumen segmen keluarga besar dengan jumlah kamar mandi 3, berapakah rentang harga sewa perbulannya di dataset ecommerce ini ?
#
# 10. Perusahaan ingin memnbuat properti rumah tinggal untuk konsumen segmen Keluarga besar, Carpet Area, Berada di kota Chennai, berapakah rentang harga sewa perbulannya di dataset ecommerce ini ?
#
# 11. Perusahaan ingin memastikan bahwa di kota Mumbai bahwa Point of Contact memakai agent, Fully Furnished, Carpet Area, dengan bathroom 2 dibawah 50 jumlahnya di ecommerce ini, apakah benar ?
# ```

# %% [markdown]
# ## 2.5 Glossary

# %% [markdown]
# ### 2.5.1 Glossary Istilah diluar kolom dataset

# %% [markdown]
# ```
# 1. BHK:
#     merupakan singkatan dari "Bedroom, Hallroom, Kitchen". Angka-angka yang tertera pada kolom BHK ini mengandung arti: jika semakin tinggi angkanya, maka semakin banyak "Bedroom"/ruang tidurnya, namun tidak seiring naik jumlah pada "Hallroom"/ruang tamu dan "Kitchen"/dapur.
#
#     Contoh:
#     1 BHK artinya: 1 Bedroom, 1 Hallroom, 1 Kitchen
#     2 BHK artinya: 2 Bedroom, 1 Hallroom, 1 Kitchen bukan 2 Befroom, 2 Hallroom, 1 Kitchen
#     5 BHK artinya: 5 Bedroom, 1 Hallroom, 1 Kitchen bukan 5 Bedroom, 5 Hallroom, 5 Kitchen
#
#     Naiknya jumlah BHK hanya menaikan jumlah Bedroomnya saja, Hallroom dan Kitchen tetap pada jumlah 1.
#
#     BHK bisa mempunyai jumlah yang desimal, itu mengartikan ada 1 Bedroom yang mempunyai ukurang yang kurang dari bedroom lainnya. Namun, pada dataset ini, tidak ditemukan BHK yang mempunyai nilai desimal.
#
#     Untuk informasi lebih lanjut mengenai BHK, bisa ditelusuri melewati link ini:
#     https://www.magicbricks.com/blog/what-is-bhk-full-form/126037.html#:~:text=BHK%20stands%20for%20'Bedroom%2C%20Hall,room)%2C%20and%20one%20Kitchen.
#
# 2. Rent:
#     Sewa pada rumah/Apartemen/flat yang dibayar tiap bulan.
#
#     Sesuai pada jawaban pembuat dataset di komentar pertanyaan melalui link ini:
#     https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset/discussion/340316
#
# 3. Size:
#     Ukuran rumah/apartemen/flat dalam hitungan kaki persegi.
#
# 4. Floor:
#     Rumah/apartemen/flat dengan cara penulisan:
#     [Lantai ke berapa] + [Total jumlah lantai]
#
#     Contoh:
#     '3 out of 5' artinya: berada pada lantai 3 dari 5 lantai
#     'Ground out of 3' artinya: berada pada lantai dasar dari 3 lantai
#     'Lower Basement out of 3' artinya: berada pada lantai basemen bawah dari 3 lantai
#
# 5. Area Type:
#     Kategori ukuran rumah/apartemen/flat dengan 3 kategori yaitu:
#
#     5.1 Carpet Area:
#         Area hanya termasuk ruangan interior.
#     5.2 Build Area:
#         Carpet Area + tangga luar + teras + balkon + area utilitas + beranda
#     5.3 Super Area:
#         Carpet Area + Build Area + Lobby + Lift + Kolam Renang + Taman
#
#     Untuk informasi lebih lanjut, bisa ditelusuri melewati link berikut ini:
#     https://www.sobha.com/blog/carpet-area-built-up-area-super-built-up-area/
#
# 6. Area Locality:
#     Nama tempat lokal dimana rumah/apartemen/flat berlokasi.
#
# 7. City:
#     Nama kota dimana rumah/apartemen/flat berlokasi.
#
# 8. Furnishing Status:
#     Status ketersediaan perabotan pada properti tempat tinggal.
#
# 9. Tenant Preferred:
#     Seringnya pilihan penyewa, apakah penyewa yang sudah menikah, tidak menikah, keduanya.
#
# 10. Bathroom:
#     Jumlah kamar mandi yang tersedia pada properti tempat tinggal.
#
# 11. Point of Contact:
#     Siapa yang harus di hubungi untuk informasi lebih lanjut mengenai properti tempat tinggal ini.
#
# 12. Tipe Keluarga:
#     Saya membuat kolom baru pada df_copy bernama "Tipe Keluarga", terbagi menjadi 2:
#
#     1. Keluarga Inti: Keluarga yang terdiri dari kedua orang tua dan anak, terdiri dari jumlah BHK yang berjumlah 1 sampai 3.
#
#     2. Keluarga Besar: Keluarga yang terdiri dari lebih dari Keluarga Inti, terdiri dari jumlah BHK yang berjumlah 4 sampai 6.
#
#
#
#
# ```

# %% [markdown]
# ### 2.5.2 Glossary Istilah didalam kolom dataset
#
# ```
# 1. Keluarga Inti / Nuclear Family:
#     Keluarga yang terdiri dari kedua orang tua dan anak
#
# 2. Keluarga Besar / Expanded Family:
#     Keluarga yang terdiri dari lebih dari Keluarga Inti
#
# 3. Segmen pasar / Market Segment / Segmentasi pasar:
#     Market segmentation is a marketing term that refers to aggregating prospective buyers into groups or segments with common needs and who respond similarly to a marketing action.
#
#     sumber:
#     https://www.investopedia.com/terms/m/marketsegmentation.asp
#
# 4. Properti tempat tinggal:
#     Properti:
#     harta berupa tanah dan bangunan serta sarana dan prasarana yang merupakan bagian yang tidak terpisahkan dari tanah dan/atau bangunan yang dimaksudkan; tanah milik dan bangunan
#
#     sumber:
#     https://kbbi.web.id/properti
#
#     Tempat tinggal:
#     Rumah (bidang dan sebagainya) tempat orang diam (tinggal).
#
#     sumber:
#     https://kbbi.lektur.id/tempat-tinggal
#
# ```

# %% [markdown]
# # 3. Data Loading

# %% [markdown]
# ## 3.1 Mengambil dataset dari internet

# %% [markdown]
# Saya mengambil dataset (dengan cara download) dari:
# https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset

# %% [markdown]
# ## 3.2 Impor pustaka yang dibutuhkan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import seaborn as sns
import statistics as stat
from scipy import stats

# %% [markdown]
# ## 3.3 Menghubungkan dataset dengan file ini

# %%
# kode ini untuk menghubungkan file ini dengan file dataset yang berupa csv
df = pd.read_csv('h8dsft_P0M1_Haidar_Farras_Latief.csv')

# %% [markdown]
# ## 3.4 Eksplorasi data 1

# %% [markdown]
# Melihat isi dataset:

# %%
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df.tail(5)
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4741  2022-05-18    2  15000  1000    3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000    1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4741          Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742  Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %% [markdown]
# Memeriksa apakah ada data yang null atau nan:

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %% [markdown]
# Melihat apa yang ada di kolom 'City':

# %%
df_city_vw = df['City'].unique()
df_city_vw
# Out:
# array(['Kolkata', 'Mumbai', 'Bangalore', 'Delhi', 'Chennai', 'Hyderabad'],
#       dtype=object)

# %% [markdown]
# Melihat tanggal upload dataset ini:

# %%
awal = df['Posted On'].min()
akhir = df['Posted On'].max()
print(f"Data dimulai dari tanggal: {awal} \nData diakhiri pada tanggal: {akhir}")
# Out:
# Data dimulai dari tanggal: 2022-04-13
# Data diakhiri pada tanggal: 2022-07-11

# %% [markdown]
# ## 3.5 Mempersiapkan dataframe untuk penjabaran

# %% [markdown]
# Menduplikasi data untuk digunakan pada analisis tanpa menghiangkan dataset aslinya:

# %%
df_copy = df.copy(deep=True)
df_copy.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %% [markdown]
# Mengubah tipe data pada kolom 'Posted On' menjadi datetime64[ns] agar bisa terhitung sebagai tanggal:

# %%
df_copy['Posted On']=pd.to_datetime(df_copy['Posted On'], format='%Y-%m-%d')
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   datetime64[ns]
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 445.1+ KB

# %%
df_copy_srt_po = df_copy.sort_values(by='Posted On')
df_copy_srt_po.head(3)
# Out:
#       Posted On  BHK    Rent  Size            Floor    Area Type  \
# 1222 2022-04-13    3  260000  1800     10 out of 11  Carpet Area
# 244  2022-04-23    2    7000   450       1 out of 3  Carpet Area
# 418  2022-04-23    1    6500   800  Ground out of 1  Carpet Area
#
#      Area Locality     City Furnishing Status  Tenant Preferred  Bathroom  \
# 1222   JVPD Scheme   Mumbai         Furnished            Family         4
# 244      safuipara  Kolkata         Furnished         Bachelors         2
# 418    Santragachi  Kolkata       Unfurnished  Bachelors/Family         1
#
#      Point of Contact
# 1222    Contact Agent
# 244     Contact Owner
# 418     Contact Owner

# %%
df_copy_srt_po.tail(3)
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type Area Locality  \
# 4546 2022-07-10    3  67000  2310      3 out of 17   Super Area      Madhapur
# 3743 2022-07-10    3  15000  1200       2 out of 5  Carpet Area   Madambakkam
# 3552 2022-07-11    2  12000   550  Ground out of 1   Super Area   Choolaimedu
#
#            City Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 4546  Hyderabad    Semi-Furnished            Family         3    Contact Agent
# 3743    Chennai       Unfurnished  Bachelors/Family         2    Contact Agent
# 3552    Chennai       Unfurnished  Bachelors/Family         2    Contact Owner

# %% [markdown]
# Membagi dataframe menjadi 2: df untuk keluarga Inti dan df untuk Keluarga Besar:

# %%
df_slct_klrg_i = [1,2,3]
df_klrg_i = df_copy.loc[df_copy['BHK'].isin(df_slct_klrg_i)]
df_klrg_i
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0    2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1    2022-05-13    2  20000   800       1 out of 3   Super Area
# 2    2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3    2022-07-04    2  10000   800       1 out of 2   Super Area
# 4    2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741 2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df_slct_klrg_b = [4,5,6]
df_klrg_b = df_copy.loc[df_copy['BHK'].isin(df_slct_klrg_b)]
df_klrg_b
# Out:
#       Posted On  BHK    Rent  Size            Floor    Area Type  \
# 83   2022-06-21    6   20000  1000       1 out of 1   Super Area
# 98   2022-04-29    4   18000  1200       1 out of 2   Super Area
# 101  2022-06-13    4   35000  1600       1 out of 5  Carpet Area
# 169  2022-04-30    4   40000  1300       1 out of 2   Super Area
# 190  2022-06-10    4   13000  1200  Ground out of 2  Carpet Area
# ...         ...  ...     ...   ...              ...          ...
# 4648 2022-07-06    6   80000  4500       1 out of 2   Super Area
# 4669 2022-07-06    4  140000  3789      9 out of 22  Carpet Area
# 4696 2022-07-06    6   30000  4200  Ground out of 2   Super Area
# 4714 2022-04-30    4   16000  1000       1 out of 3   Super Area
# 4716 2022-04-29    4  110000  3250     12 out of 17  Carpet Area
#
#                         Area Locality       City Furnishing Status  \
# 83                           Sonarpur    Kolkata    Semi-Furnished
# ...

# %% [markdown]
# Membuat kolom baru bernama 'Tipe Keluarga' untuk menandakan tipe Keluarga Inti atau Besar:

# %%
df_copy['Tipe Keluarga'] = df_copy['BHK'].apply(lambda x: "Keluarga Inti" if x in [1,2,3] else "Keluarga Besar")
df_copy
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0    2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1    2022-05-13    2  20000   800       1 out of 3   Super Area
# 2    2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3    2022-07-04    2  10000   800       1 out of 2   Super Area
# 4    2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741 2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %% [markdown]
# # 4. Analisis dan perhitungan

# %% [markdown]
# ## 4.1 Eksplorasi data 2

# %% [markdown]
# Melihat semua kategori yang ada pada dataset ini:

# %% [markdown]
# Berdasarkan Tipe Keluarga:

# %%
df_copy['Tipe Keluarga'].value_counts()
# Out:
# Keluarga Inti     4530
# Keluarga Besar     216
# Name: Tipe Keluarga, dtype: int64

# %%
df_copy.groupby('Tipe Keluarga').agg(Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean), Mode_Floor=('Floor',stat.mode), Mode_Area_Type=('Area Type',stat.mode), Mode_Area_Locality=('Area Locality',stat.mode), Mode_City=('City',stat.mode), Mode_Furnishing_Status=('Furnishing Status',stat.mode), Mode_Tenant_Preferred=('Tenant Preferred', stat.mode), Mean_Bathroom=('Bathroom', np.mean), Mode_Point_of_Contact=('Point of Contact', stat.mode))
# Out:
#                     Mean_Rent    mean_Size  Mode_Floor Mode_Area_Type  \
# Tipe Keluarga
# Keluarga Besar  176633.800926  2454.361111  2 out of 4    Carpet Area
# Keluarga Inti    28239.739294   896.593598  1 out of 2     Super Area
#
#                Mode_Area_Locality Mode_City Mode_Furnishing_Status  \
# Tipe Keluarga
# Keluarga Besar        Bandra West    Mumbai         Semi-Furnished
# Keluarga Inti         Bandra West    Mumbai         Semi-Furnished
#
#                Mode_Tenant_Preferred  Mean_Bathroom Mode_Point_of_Contact
# Tipe Keluarga
# Keluarga Besar      Bachelors/Family       4.083333         Contact Agent
# Keluarga Inti       Bachelors/Family       1.864901         Contact Owner

# %%
df_typ = df_copy['Area Type'].value_counts()
df_typ
# Out:
# Super Area     2446
# Carpet Area    2298
# Built Area        2
# Name: Area Type, dtype: int64

# %%
df_copy.groupby('Area Type').agg(
Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean), Mode_Floor=('Floor',stat.mode), 
Mode_Area_Locality=('Area Locality',stat.mode), Mode_City=('City',stat.mode), Mode_Furnishing_Status=('Furnishing Status',stat.mode), 
Mode_Tenant_Preferred=('Tenant Preferred', stat.mode), Mean_Bathroom=('Bathroom', np.mean), 
Mode_Point_of_Contact=('Point of Contact', stat.mode), Mode_Tipe_Keluarga=('Tipe Keluarga',stat.mode))
# Out:
#                 Mean_Rent    mean_Size  Mode_Floor   Mode_Area_Locality  \
# Area Type
# Built Area   10500.000000   750.000000  1 out of 2  Chromepet, GST Road
# Carpet Area  52385.897302  1020.127067  2 out of 4          Bandra West
# Super Area   18673.396566   918.217089  1 out of 2      Electronic City
#
#              Mode_City Mode_Furnishing_Status Mode_Tenant_Preferred  \
# Area Type
# Built Area     Chennai              Furnished      Bachelors/Family
# Carpet Area     Mumbai         Semi-Furnished      Bachelors/Family
# Super Area   Hyderabad         Semi-Furnished      Bachelors/Family
#
#              Mean_Bathroom Mode_Point_of_Contact Mode_Tipe_Keluarga
# Area Type
# Built Area        1.500000         Contact Owner      Keluarga Inti
# Carpet Area       2.134030         Contact Agent      Keluarga Inti
# Super Area        1.808258         Contact Owner      Keluarga Inti

# %%
df_flr = df_copy['Floor'].value_counts()
df_flr
# Out:
# 1 out of 2         379
# Ground out of 2    350
# 2 out of 3         312
# 2 out of 4         308
# 1 out of 3         293
#                   ...
# 11 out of 31         1
# 50 out of 75         1
# 18 out of 26         1
# 12 out of 27         1
# 23 out of 34         1
# Name: Floor, Length: 480, dtype: int64

# %%
df_copy.groupby('Floor').agg(
Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean),Mode_Area_Type=('Area Type',stat.mode),
Mode_Area_Locality=('Area Locality',stat.mode), Mode_City=('City',stat.mode), Mode_Furnishing_Status=('Furnishing Status',stat.mode), 
Mode_Tenant_Preferred=('Tenant Preferred', stat.mode), Mean_Bathroom=('Bathroom', np.mean), 
Mode_Point_of_Contact=('Point of Contact', stat.mode), Mode_Tipe_Keluarga=('Tipe Keluarga',stat.mode))
# Out:
#                               Mean_Rent    mean_Size Mode_Area_Type  \
# Floor
# 1                          15000.000000  1085.000000     Super Area
# 1 out of 1                 22667.522388   960.410448    Carpet Area
# 1 out of 10                30500.000000  1026.250000    Carpet Area
# 1 out of 11                30000.000000  1020.000000    Carpet Area
# 1 out of 12                33500.000000  1300.000000    Carpet Area
# ...                                 ...          ...            ...
# Upper Basement out of 4     7500.000000   266.666667    Carpet Area
# Upper Basement out of 40  150000.000000  1330.000000    Carpet Area
# Upper Basement out of 5    15500.000000   600.000000    Carpet Area
# Upper Basement out of 7    25500.000000   395.000000    Carpet Area
# Upper Basement out of 9    36500.000000   800.000000    Carpet Area
#
#                                               Mode_Area_Locality  Mode_City  \
# Floor
# ...

# %%
df_cty = df_copy['City'].value_counts()
df_cty
# Out:
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524
# Name: City, dtype: int64

# %%
df_copy.groupby('City').agg(
Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean),Mode_Floor=('Floor',stat.mode), Mode_Area_Type=('Area Type',stat.mode),
Mode_Area_Locality=('Area Locality',stat.mode), Mode_Furnishing_Status=('Furnishing Status',stat.mode), 
Mode_Tenant_Preferred=('Tenant Preferred', stat.mode), Mean_Bathroom=('Bathroom', np.mean), 
Mode_Point_of_Contact=('Point of Contact', stat.mode), Mode_Tipe_Keluarga=('Tipe Keluarga',stat.mode))
# Out:
#               Mean_Rent    mean_Size       Mode_Floor Mode_Area_Type  \
# City
# Bangalore  24966.365688   985.925508       2 out of 3     Super Area
# Chennai    21614.092031  1031.713805       1 out of 2     Super Area
# Delhi      29461.983471   786.406612       2 out of 4    Carpet Area
# Hyderabad  20555.048387  1186.669355       2 out of 3     Super Area
# Kolkata    11645.173664   787.366412  Ground out of 2    Carpet Area
# Mumbai     85321.204733   905.904321       5 out of 7    Carpet Area
#
#                 Mode_Area_Locality Mode_Furnishing_Status  \
# City
# Bangalore          Electronic City         Semi-Furnished
# Chennai                  Velachery         Semi-Furnished
# Delhi                  Laxmi Nagar         Semi-Furnished
# Hyderabad               Gachibowli         Semi-Furnished
# Kolkata    Salt Lake City Sector 2            Unfurnished
# Mumbai                 Bandra West         Semi-Furnished
#
# ...

# %%
df_lclty = df_copy['Area Locality'].value_counts()
df_lclty
# Out:
# Bandra West                                37
# Gachibowli                                 29
# Electronic City                            24
# Velachery                                  22
# Miyapur, NH 9                              22
#                                            ..
# Kengeri Upanagara                           1
# Ittamadu, Banashankari, Outer Ring Road     1
# Rmv Extension, Armane Nagar                 1
# snv la                                      1
# Manikonda, Hyderabad                        1
# Name: Area Locality, Length: 2235, dtype: int64

# %%
df_copy.groupby('Area Locality').agg(
Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean),Mode_Floor=('Floor',stat.mode), Mode_Area_Type=('Area Type',stat.mode), Mode_Furnishing_Status=('Furnishing Status',stat.mode), 
Mode_Tenant_Preferred=('Tenant Preferred', stat.mode), Mean_Bathroom=('Bathroom', np.mean), 
Mode_Point_of_Contact=('Point of Contact', stat.mode), Mode_Tipe_Keluarga=('Tipe Keluarga',stat.mode))
# Out:
#                                           Mean_Rent  mean_Size  \
# Area Locality
#  Beeramguda, Ramachandra Puram, NH 9  200000.000000     8000.0
#  in Boduppal, NH 2 2                    4700.000000      850.0
#  in Erragadda, NH 9                    12000.000000     1150.0
#  in Miyapur, NH 9                      15000.000000     1550.0
# 117 Residency, Chembur East            47000.000000      650.0
# ...                                             ...        ...
# vanamali chs ghatla, Ghatla            52000.000000      750.0
# venkatapuram                           13500.000000      600.0
# venkatesa perumal nagar                 9000.000000      700.0
# villvam towers tnhb colony             15000.000000      600.0
# whitefield                             57458.333333     1960.0
#
#                                            Mode_Floor Mode_Area_Type  \
# Area Locality
#  Beeramguda, Ramachandra Puram, NH 9  Ground out of 4     Super Area
# ...

# %%
df_fs = df_copy['Furnishing Status'].value_counts()
df_fs
# Out:
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: Furnishing Status, dtype: int64

# %%
df_copy.groupby('Furnishing Status').agg(
Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean),Mode_Floor=('Floor',stat.mode), Mode_Area_Type=('Area Type',stat.mode),
Mode_Area_Locality=('Area Locality',stat.mode), 
Mode_Tenant_Preferred=('Tenant Preferred', stat.mode), Mean_Bathroom=('Bathroom', np.mean), 
Mode_Point_of_Contact=('Point of Contact', stat.mode), Mode_Tipe_Keluarga=('Tipe Keluarga',stat.mode))
# Out:
#                       Mean_Rent    mean_Size       Mode_Floor Mode_Area_Type  \
# Furnishing Status
# Furnished          56110.305882  1047.386765  Ground out of 2    Carpet Area
# Semi-Furnished     38718.810751  1077.342959       2 out of 4     Super Area
# Unfurnished        22461.635813   801.316253       1 out of 2     Super Area
#
#                           Mode_Area_Locality Mode_Tenant_Preferred  \
# Furnishing Status
# Furnished                        Bandra West      Bachelors/Family
# Semi-Furnished                   Bandra West      Bachelors/Family
# Unfurnished        kst chattarpur Apartments      Bachelors/Family
#
#                    Mean_Bathroom Mode_Point_of_Contact Mode_Tipe_Keluarga
# Furnishing Status
# Furnished               2.127941         Contact Owner      Keluarga Inti
# Semi-Furnished          2.099511         Contact Owner      Keluarga Inti
# Unfurnished             1.739394         Contact Owner      Keluarga Inti

# %%
df_copy['Tenant Preferred'].value_counts()
# Out:
# Bachelors/Family    3444
# Bachelors            830
# Family               472
# Name: Tenant Preferred, dtype: int64

# %%
df_copy.groupby('Tenant Preferred').agg(
Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean),Mode_Floor=('Floor',stat.mode), Mode_Area_Type=('Area Type',stat.mode), Mode_Furnishing_Status=('Furnishing Status',stat.mode),
Mode_Area_Locality=('Area Locality',stat.mode), Mean_Bathroom=('Bathroom', np.mean), 
Mode_Point_of_Contact=('Point of Contact', stat.mode), Mode_Tipe_Keluarga=('Tipe Keluarga',stat.mode))
# Out:
#                      Mean_Rent    mean_Size       Mode_Floor Mode_Area_Type  \
# Tenant Preferred
# Bachelors         42143.793976  1015.109639       2 out of 4    Carpet Area
# Bachelors/Family  31210.792683   930.271196  Ground out of 2     Super Area
# Family            50020.341102  1155.330508       1 out of 2    Carpet Area
#
#                  Mode_Furnishing_Status         Mode_Area_Locality  \
# Tenant Preferred
# Bachelors                   Unfurnished  kst chattarpur Apartments
# Bachelors/Family         Semi-Furnished                Bandra West
# Family                   Semi-Furnished                 Vadapalani
#
#                   Mean_Bathroom Mode_Point_of_Contact Mode_Tipe_Keluarga
# Tenant Preferred
# Bachelors              2.026506         Contact Agent      Keluarga Inti
# Bachelors/Family       1.900697         Contact Owner      Keluarga Inti
# Family                 2.334746         Contact Agent      Keluarga Inti

# %%
df_poc = df_copy['Point of Contact'].value_counts()
df_poc
# Out:
# Contact Owner      3216
# Contact Agent      1529
# Contact Builder       1
# Name: Point of Contact, dtype: int64

# %%
df_copy.groupby('Point of Contact').agg(
Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean),Mode_Floor=('Floor',stat.mode), Mode_Area_Type=('Area Type',stat.mode), Mode_Furnishing_Status=('Furnishing Status',stat.mode),
Mode_Area_Locality=('Area Locality',stat.mode), Mode_Tenant_Preferred=('Tenant Preferred', stat.mode), Mean_Bathroom=('Bathroom', np.mean), Mode_Tipe_Keluarga=('Tipe Keluarga',stat.mode))
# Out:
#                      Mean_Rent    mean_Size  Mode_Floor Mode_Area_Type  \
# Point of Contact
# Contact Agent     73481.158927  1164.812296  2 out of 4    Carpet Area
# Contact Builder    5500.000000   400.000000  1 out of 2     Super Area
# Contact Owner     16704.206468   873.853545  1 out of 2     Super Area
#
#                  Mode_Furnishing_Status   Mode_Area_Locality  \
# Point of Contact
# Contact Agent            Semi-Furnished          Bandra West
# Contact Builder             Unfurnished  Ramanthapur, NH 2 2
# Contact Owner            Semi-Furnished      Electronic City
#
#                  Mode_Tenant_Preferred  Mean_Bathroom Mode_Tipe_Keluarga
# Point of Contact
# Contact Agent         Bachelors/Family       2.386527      Keluarga Inti
# Contact Builder       Bachelors/Family       1.000000      Keluarga Inti
# Contact Owner         Bachelors/Family       1.766169      Keluarga Inti

# %%
df_poc = df_copy['BHK'].value_counts()
df_poc
# Out:
# 2    2265
# 1    1167
# 3    1098
# 4     189
# 5      19
# 6       8
# Name: BHK, dtype: int64

# %%
df_copy.groupby('BHK').agg(
Mean_Rent=('Rent',np.mean), mean_Size=('Size',np.mean),Mode_Floor=('Floor',stat.mode), Mode_Area_Type=('Area Type',stat.mode), Mode_Furnishing_Status=('Furnishing Status',stat.mode),
Mode_Area_Locality=('Area Locality',stat.mode), Mode_Tenant_Preferred=('Tenant Preferred', stat.mode), Mean_Bathroom=('Bathroom', np.mean), Mode_Point_of_Contact=('Point of Contact', stat.mode), Mode_Tipe_Keluarga=('Tipe Keluarga',stat.mode))
# Out:
#          Mean_Rent    mean_Size       Mode_Floor Mode_Area_Type  \
# BHK
# 1     14139.223650   478.907455       1 out of 2     Super Area
# 2     22113.864018   852.072848       1 out of 2     Super Area
# 3     55863.062842  1432.367031       2 out of 4    Carpet Area
# 4    168864.555556  2382.190476       2 out of 4    Carpet Area
# 5    297500.000000  2910.947368       2 out of 2    Carpet Area
# 6     73125.000000  3075.000000  Ground out of 1     Super Area
#
#     Mode_Furnishing_Status             Mode_Area_Locality  \
# BHK
# 1              Unfurnished        Salt Lake City Sector 5
# 2           Semi-Furnished                Electronic City
# 3           Semi-Furnished                     Gachibowli
# 4           Semi-Furnished             Trump Tower, Worli
# 5              Unfurnished  Runwal Elegante, Andheri West
# 6           Semi-Furnished                       Sonarpur
#
#     Mode_Tenant_Preferred  Mean_Bathroom Mode_Point_of_Contact  \
# BHK
# ...

# %% [markdown]
# ## 4.2 Analisis data sesuai penjabaran

# %% [markdown]
# ### 4.2.1 Penjabaran 1
# ```
# 1. Apa Rata-rata, Median, dan Modus pada biaya sewa perbulan, ukuran ruangan, dan Jumlah kamar mandi ?
# ```

# %%
df_mean_1 = df_copy[['Rent','Size','Bathroom']].mean()
df_mean_2= pd.DataFrame(df_mean_1)
df_mean_2
# Out:
#                      0
# Rent      34993.451327
# Size        967.490729
# Bathroom      1.965866

# %%
df_median_1 = df_copy[['Rent','Size','Bathroom']].median()
df_median_2 = pd.DataFrame(df_median_1).T
df_median_2
# Out:
#       Rent   Size  Bathroom
# 0  16000.0  850.0       2.0

# %%
df_mode_1 = df_copy[['Rent','Size','Bathroom']].mode()
df_mode_2= pd.DataFrame(df_mode_1)
df_mode_2
# Out:
#     Rent  Size  Bathroom
# 0  15000  1000         2

# %% [markdown]
# ### 4.2.2 Penjabaran 2
# ```
# 2. Apa Rata-rata dan median dari biaya sewa, ukuran ruangan, Jumlah kamar mandi untuk target konsumen keluarga inti dan keluarga besar ?
# ```

# %%
df_2klrg_mean = df_copy[['Tipe Keluarga','Rent','Size','Bathroom']]
df2klrg_mean_1 = df_2klrg_mean.groupby(['Tipe Keluarga']).mean()
df2klrg_mean_1
# Out:
#                          Rent         Size  Bathroom
# Tipe Keluarga
# Keluarga Besar  176633.800926  2454.361111  4.083333
# Keluarga Inti    28239.739294   896.593598  1.864901

# %%
df_2klrg_median = df_copy[['Tipe Keluarga','Rent','Size','Bathroom']]
df2klrg_median_1 = df_2klrg_median.groupby(['Tipe Keluarga']).median()
df2klrg_median_1
# Out:
#                     Rent    Size  Bathroom
# Tipe Keluarga
# Keluarga Besar  135000.0  2400.0       4.0
# Keluarga Inti    15000.0   800.0       2.0

# %%
slsh_rnt = 176633.800926 - 28239.739294
slsh_size = 2454.361111 - 896.593598
slsh_bath = 4.083333 - 1.864901
print(f"Dari ketersediaan keluarga inti dan besar:\n \nSelisih biaya sewa perbulan : {slsh_rnt} \nSelisih dari ukuran properti: {slsh_size} \nSelisih dari kamar mandi: {slsh_bath}")
# Out:
# Dari ketersediaan keluarga inti dan besar:
#
# Selisih biaya sewa perbulan : 148394.061632
# Selisih dari ukuran properti: 1557.7675130000002
# Selisih dari kamar mandi: 2.218432

# %% [markdown]
# ### 4.2.3 Penjabaran 3
# ```
# 3. Apa grafik perbandingan ketersediaan jumlah kamar mandi pada masing-masing kriteria Tipe Keluarga ?
# ```

# %%
df_klrg_i['Bathroom'].value_counts()
# Out:
# 2     2275
# 1     1473
# 3      717
# 4       57
# 5        6
# 6        1
# 10       1
# Name: Bathroom, dtype: int64

# %% [markdown]
# Ketersediaan kamar mandi kriteria Tipe Keluarga Inti:

# %%
df_klrg_bath_plt = df_klrg_i['Bathroom'].value_counts().plot(kind='bar')
df_klrg_bath_plt
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ketersediaan kamar mandi kriteria Tipe Keluarga Besar:

# %%
df_klrg_bath_plt = df_klrg_b['Bathroom'].value_counts().plot(kind='bar')
df_klrg_bath_plt
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.2.4 Penjabaran 4
# ```
# 4. Seberapa beda harga sewa tiap bulan pada kategori area untuk keluarga inti dan keluarga besar ?
# ```

# %%
df_slsh_sw_2klrg = df_copy[['Tipe Keluarga','Rent']]
df_slsh_sw_2klrg_hsl = df_slsh_sw_2klrg.groupby(['Tipe Keluarga']).mean().T
df_slsh_sw_2klrg_hsl['Selisihnya'] = df_slsh_sw_2klrg_hsl['Keluarga Besar'] - df_slsh_sw_2klrg_hsl['Keluarga Inti']
df_slsh_sw_2klrg_hsl
# Out:
# Tipe Keluarga  Keluarga Besar  Keluarga Inti     Selisihnya
# Rent            176633.800926   28239.739294  148394.061632

# %%
df_slsh_sw_2klrg_hsl.to_csv('df_slsh_sw_2klrg_hsl.csv')

# %%
df_slsh_sw_2klrg_hsl.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Hasil:
# beda harga sewa tiap bulan pada kategori area untuk keluarga inti dan keluarga besar adalah 148394.061632

# %% [markdown]
# ### 4.2.5 Penjabaran 5
# ```
# 5. Kota apa dengan rata-rata harga termurah pada keluarga inti dan keluarga besar ?
# ```

# %%
df_klrg_i_city = df_klrg_i.groupby('City')['Rent'].mean().sort_values(ascending=True)
df_klrg_i_city
df_klrg_i_city_df = pd.DataFrame(df_klrg_i_city)
df_klrg_i_city_df
# Out:
#                    Rent
# City
# Kolkata    11252.100000
# Hyderabad  17665.206235
# Chennai    19424.632065
# Bangalore  22619.003476
# Delhi      23602.286972
# Mumbai     64963.075450

# %%
df_klrg_i_city = df_klrg_i.groupby('City')['Rent'].mean().sort_values()
df_klrg_i_city
df_klrg_i_city_df = pd.DataFrame(df_klrg_i_city)
df_klrg_i_city_df.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City'>

# %%
df_klrg_b_city = df_klrg_b.groupby('City')['Rent'].mean().sort_values()
df_klrg_b_city
df_klrg_b_city_df = pd.DataFrame(df_klrg_b_city)
df_klrg_b_city_df
# Out:
#                     Rent
# City
# Kolkata     25964.285714
# Hyderabad   91441.176471
# Chennai    100708.333333
# Bangalore  113043.478261
# Delhi      119416.243243
# Mumbai     300535.714286

# %%
df_klrg_b_city = df_klrg_b.groupby('City')['Rent'].mean().sort_values()
df_klrg_b_city
df_klrg_b_city_df = pd.DataFrame(df_klrg_b_city)
df_klrg_b_city_df.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# Hasil:
# Kota dengan rata-rata harga termurah pada keluarga inti dan keluarga besar, dua-duanya adalah Kolkata.

# %% [markdown]
# ### 4.2.6 Penjabaran 6
# ```
# Apakah ada hubungan Area Type dengan Point of Contact ?
# ```

# %% [markdown]
# Untuk melakukan test ini, saya gunakan hipotesis:
# ```
# H0: Area Type dan Point of Contact tidak mempunyai hubungan
# H1: Area Type dan Point of Contact mempunyai hubungan
# ```
# Dikarenakan kedua variabel ini mempunyai isi konten string atau merupakan data ketegori, maka saya gunakan Chi Square Test

# %% [markdown]
# Untuk melakukan Chi Square Test, diperlukan 4 asumsi:

# %% [markdown]
# 1. Kedua variabel adalah kategori

# %% [markdown]
# 2. Semua observasi tidak bergantung (Independent)

# %% [markdown]
# 3. Sel atau isi konten dari tabel kontigensi sama-sama eksklusif atau isi konten yang melakukan pengulangan

# %% [markdown]
# 4. Expected value pada masing-masing sel harus berjumah 5 atau lebih sekiranya 80% dari cel

# %%
contingency_table_contoh = pd.crosstab(df_copy["Area Type"], df_copy["Point of Contact"])
contingency_table_contoh
# Out:
# Point of Contact  Contact Agent  Contact Builder  Contact Owner
# Area Type
# Built Area                    0                0              2
# Carpet Area                1363                0            935
# Super Area                  166                1           2279

# %% [markdown]
# Pada tabel diatas ini terlihat bahwa terdapat sel yang berada pada bawah 5. Walaupun saya hitung expected valuenya, ada sel yang mendapatkan hasil dibawah 5, maka itu saya keluarkan kolom 'Contact Builder' dan baris 'Built Area' sehingga tertinggal angka yang bisa diolah pada Chi Square test ini.

# %%
df_chi_1 = df_copy[df_copy["Point of Contact"].str.contains("Contact Builder") == False]
df_chi_2 = df_chi_1[df_chi_1["Area Type"].str.contains("Built Area") == False]

contingency_table = pd.crosstab(df_chi_2["Area Type"], df_chi_2["Point of Contact"])
contingency_table
# Out:
# Point of Contact  Contact Agent  Contact Owner
# Area Type
# Carpet Area                1363            935
# Super Area                  166           2279

# %% [markdown]
# Dengan filter data ini, data dapat dimasukan kedalam Chi Square Test namun dengan informasi tambahan bahwa ada data yang berkurang.

# %%
# Melakukan test chi
stat, p, dof, expected = stats.chi2_contingency(contingency_table)
print('p=%.12f' % (p))
if p > 0.05:
  print("Probably Independent")
else: 
  print("Probably Dependent")
# Out:
# p=0.000000000000
# Probably Dependent

# %% [markdown]
# Hasil menunjukan untuk menolak H0 yang berarti: Area Type dan Point of Contact mempunyai hubungan.

# %% [markdown]
# ### 4.2.7 Penjabaran 7
# ```
# 7. Apakah ada hubungan Furnishing Status dan Tipe Keluarga ?
# ```

# %% [markdown]
# Untuk melakukan test ini, saya gunakan hipotesis:
# ```
# H0: Furnishing Status dan Tipe Keluarga tidak mempunyai hubungan
# H1: Furnishing Status dan Tipe Keluarga mempunyai hubungan
# ```
# Dikarenakan kedua variabel ini mempunyai isi konten string atau merupakan data ketegori, maka saya gunakan Chi Square Test

# %%
contingency_table2 = pd.crosstab(df_copy["Tenant Preferred"], df_copy["Tipe Keluarga"])
contingency_table2
# Out:
# Tipe Keluarga     Keluarga Besar  Keluarga Inti
# Tenant Preferred
# Bachelors                     39            791
# Bachelors/Family             143           3301
# Family                        34            438

# %%
# Melakukan test chi
stat, p, dof, expected = stats.chi2_contingency(contingency_table2)
print('p=%.3f' % (p))
if p > 0.05:
  print("Probably Independent")
else: 
  print("Probably Dependent")
# Out:
# p=0.011
# Probably Dependent

# %% [markdown]
# Hasil menunjukan untuk menolak H0 yang berarti: Furnishing Status dan Tipe Keluarga mempunyai hubungan.

# %% [markdown]
# ### 4.2.8 Penjabaran 8
# ```
# 8. Apakah ada hubungan Furnishing Status dan Tenant Preferred
# ```

# %% [markdown]
# Untuk melakukan test ini, saya gunakan hipotesis:
# ```
# H0: Furnishing Status dan Tenant Preferred tidak mempunyai hubungan
# H1: Furnishing Status dan Tenant Preferred mempunyai hubungan
# ```
# Dikarenakan kedua variabel ini mempunyai isi konten string atau merupakan data ketegori, maka saya gunakan Chi Square Test

# %%
contingency_table1 = pd.crosstab(df_copy["Furnishing Status"], df_copy["Tenant Preferred"])
contingency_table1
# Out:
# Tenant Preferred   Bachelors  Bachelors/Family  Family
# Furnishing Status
# Furnished                 97               508      75
# Semi-Furnished           324              1675     252
# Unfurnished              409              1261     145

# %%
# Melakukan test chi
stat, p, dof, expected = stats.chi2_contingency(contingency_table1)
print('p=%.12f' % (p))
if p > 0.05:
  print("Probably Independent")
else: 
  print("Probably Dependent")
# Out:
# p=0.000000000008
# Probably Dependent

# %% [markdown]
# Hasil menunjukan untuk menolak H0 yang berarti: Furnishing Status dan Tenant Preferred mempunyai hubungan.

# %% [markdown]
# ### 4.2.9 Penjabaran 9
# ```
# 9. Perusahaan ingin membuat properti rumah tinggal untuk konsumen segmen keluarga besar
# dengan jumlah kamar mandi 3, berapakah rentang harga sewa perbulannya di dataset ecommerce ini ?
# ```

# %%
df_klrg_b
# Out:
#       Posted On  BHK    Rent  Size            Floor    Area Type  \
# 83   2022-06-21    6   20000  1000       1 out of 1   Super Area
# 98   2022-04-29    4   18000  1200       1 out of 2   Super Area
# 101  2022-06-13    4   35000  1600       1 out of 5  Carpet Area
# 169  2022-04-30    4   40000  1300       1 out of 2   Super Area
# 190  2022-06-10    4   13000  1200  Ground out of 2  Carpet Area
# ...         ...  ...     ...   ...              ...          ...
# 4648 2022-07-06    6   80000  4500       1 out of 2   Super Area
# 4669 2022-07-06    4  140000  3789      9 out of 22  Carpet Area
# 4696 2022-07-06    6   30000  4200  Ground out of 2   Super Area
# 4714 2022-04-30    4   16000  1000       1 out of 3   Super Area
# 4716 2022-04-29    4  110000  3250     12 out of 17  Carpet Area
#
#                         Area Locality       City Furnishing Status  \
# 83                           Sonarpur    Kolkata    Semi-Furnished
# ...

# %%
df_klrg_b_3b = df_klrg_b.loc[df_klrg_b['Bathroom'] == 3, ['City','Rent']]
df_klrg_b_3b
# Out:
#            City    Rent
# 101     Kolkata   35000
# 169     Kolkata   40000
# 233     Kolkata   35000
# 275     Kolkata   30000
# 397     Kolkata   35000
# 634      Mumbai  210000
# 798      Mumbai  200000
# 857      Mumbai  150000
# 994      Mumbai  140000
# 1122     Mumbai  300000
# 1136     Mumbai   45000
# 1143     Mumbai  290000
# 1182     Mumbai  130000
# 1378     Mumbai  270000
# 1502  Bangalore   61500
# 1961  Bangalore   15000
# 1974  Bangalore   30000
# 2050  Bangalore   42500
# 2156  Bangalore   75000
# 2375  Bangalore   65000
# 2434      Delhi   55000
# 2606      Delhi   40000
# 2658      Delhi   60000
# 2667      Delhi   36000
# 2681      Delhi   35000
# 3303    Chennai   65000
# 3504    Chennai   70000
# 3856    Chennai   40000
# 3926  Hyderabad   25000
# 3941  Hyderabad   25000
# 3953  Hyderabad   45000
# 4522  Hyderabad   60000

# %%
df_klrg_3b_m = df_klrg_b_3b.loc[df_klrg_b_3b['City'] == 'Mumbai', ['City','Rent']]
df_klrg_3b_m
# Out:
#         City    Rent
# 634   Mumbai  210000
# 798   Mumbai  200000
# 857   Mumbai  150000
# 994   Mumbai  140000
# 1122  Mumbai  300000
# 1136  Mumbai   45000
# 1143  Mumbai  290000
# 1182  Mumbai  130000
# 1378  Mumbai  270000

# %%
awal = df_klrg_3b_m['Rent'].min()
akhir = df_klrg_3b_m['Rent'].max()
print(f"Biaya sewa perbulan pada segmen keluarga besar dengan jumlah bathroom 3 adalah diantara {awal} sampai {akhir}")
# Out:
# Biaya sewa perbulan pada segmen keluarga besar dengan jumlah bathroom 3 adalah diantara 45000 sampai 300000

# %% [markdown]
# ### 4.2.10 Penjabaran 10
# ```
# 10. Perusahaan ingin memnbuat properti rumah tinggal untuk konsumen segmen Keluarga inti,
# Carpet Area, Berada di kota Chennai, jumlah bathroom 2, berapakah rentang harga sewa perbulannya di dataset ecommerce ini ?
# ```

# %%
df_klrg_i
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0    2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1    2022-05-13    2  20000   800       1 out of 3   Super Area
# 2    2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3    2022-07-04    2  10000   800       1 out of 2   Super Area
# 4    2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741 2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df_klrg_i_ca = df_klrg_i.loc[df_klrg_i['Area Type'] == 'Carpet Area', ['City','Bathroom','Rent']]
df_klrg_i_ca
# Out:
#            City  Bathroom   Rent
# 4       Kolkata         1   7500
# 8       Kolkata         2  26000
# 9       Kolkata         2  10000
# 10      Kolkata         2  25000
# 11      Kolkata         1   5000
# ...         ...       ...    ...
# 4739  Hyderabad         2  25000
# 4741  Hyderabad         2  15000
# 4743  Hyderabad         3  35000
# 4744  Hyderabad         2  45000
# 4745  Hyderabad         2  15000
#
# [2137 rows x 3 columns]

# %%
df_klrg_i_2b = df_klrg_i_ca.loc[df_klrg_i_ca['Bathroom'] == 2, ['City','Rent']]
df_klrg_i_2b
# Out:
#            City   Rent
# 8       Kolkata  26000
# 9       Kolkata  10000
# 10      Kolkata  25000
# 14      Kolkata   8500
# 15      Kolkata  40000
# ...         ...    ...
# 4738  Hyderabad  17000
# 4739  Hyderabad  25000
# 4741  Hyderabad  15000
# 4744  Hyderabad  45000
# 4745  Hyderabad  15000
#
# [1061 rows x 2 columns]

# %%
df_klrg_i_chn = df_klrg_i_2b.loc[df_klrg_i_2b['City'] == 'Chennai', ['Rent']]
df_klrg_i_chn
# Out:
#        Rent
# 2992  15000
# 3005  23000
# 3006  10000
# 3027  18000
# 3032  10000
# ...     ...
# 3851  25000
# 3853  18000
# 3854   9500
# 3870  10000
# 3877  23000
#
# [173 rows x 1 columns]

# %%
df_klrg_i_chn['Rent_count'] = df_klrg_i_chn.groupby('Rent')['Rent'].transform('count')
df_klrg_i_chn
# Out:
#        Rent  Rent_count
# 2992  15000          19
# 3005  23000           7
# 3006  10000          12
# 3027  18000           9
# 3032  10000          12
# ...     ...         ...
# 3851  25000           7
# 3853  18000           9
# 3854   9500           3
# 3870  10000          12
# 3877  23000           7
#
# [173 rows x 2 columns]

# %%
df_klrg_i_chn_srtd = df_klrg_i_chn.sort_values(by=['Rent_count'], ascending=False)
df_klrg_i_chn_srtd
# Out:
#        Rent  Rent_count
# 2992  15000          19
# 3251  15000          19
# 3116  15000          19
# 3115  15000          19
# 3173  15000          19
# ...     ...         ...
# 3261  13500           1
# 3447  12500           1
# 3797  22999           1
# 3790  27999           1
# 3523  34000           1
#
# [173 rows x 2 columns]

# %%
df_klrg_i_chn_srtd.groupby('Rent_count')['Rent'].sum().plot(title='Jumlah biaya sewa perbulan pada segmen keluarga inti, Carpet Area, jumlah bathroom 3 ', kind='bar', figsize=(30,7));

# %%
awal = df_klrg_i_chn['Rent'].min()
akhir = df_klrg_i_chn['Rent'].max()
print(f"Biaya sewa perbulan pada segmen keluarga inti, Carpet Area, jumlah bathroom 3 adalah diantara {awal} sampai {akhir}")
# Out:
# Biaya sewa perbulan pada segmen keluarga inti, Carpet Area, jumlah bathroom 3 adalah diantara 7000 sampai 600000

# %% [markdown]
# ### 4.2.11 Penjabaran 11
# ```
# 11. Perusahaan ingin memastikan bahwa di kota Mumbai bahwa untuk segemen keluarga inti, Point of Contact memakai agent, Fully Furnished, Carpet Area,
# dengan bathroom 2 dibawah 50 jumlahnya di ecommerce ini, apakah benar ? Berapakah rentang harganya ?
# ```

# %%
df_klrg_i
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0    2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1    2022-05-13    2  20000   800       1 out of 3   Super Area
# 2    2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3    2022-07-04    2  10000   800       1 out of 2   Super Area
# 4    2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741 2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df_klrg_i_m = df_klrg_i.loc[df_klrg_i['City'] == 'Mumbai', ['City','Point of Contact','Furnishing Status','Bathroom','Rent']]
df_klrg_i_m
# Out:
#         City Point of Contact Furnishing Status  Bathroom   Rent
# 524   Mumbai    Contact Owner    Semi-Furnished         1  25000
# 525   Mumbai    Contact Agent         Furnished         2  70000
# 526   Mumbai    Contact Agent         Furnished         1  45000
# 527   Mumbai    Contact Agent       Unfurnished         3  75000
# 528   Mumbai    Contact Owner         Furnished         1  14000
# ...      ...              ...               ...       ...    ...
# 1490  Mumbai    Contact Agent       Unfurnished         2  45000
# 1491  Mumbai    Contact Agent    Semi-Furnished         2  65000
# 1492  Mumbai    Contact Owner    Semi-Furnished         3  65000
# 1493  Mumbai    Contact Owner    Semi-Furnished         1  35000
# 1494  Mumbai    Contact Agent         Furnished         2  90000
#
# [888 rows x 5 columns]

# %%
df_klrg_i_m_ca = df_klrg_i_m.loc[df_klrg_i_m['Point of Contact'] == 'Contact Agent', ['Point of Contact','Furnishing Status','Bathroom','Rent']]
df_klrg_i_m_ca
# Out:
#      Point of Contact Furnishing Status  Bathroom   Rent
# 525     Contact Agent         Furnished         2  70000
# 526     Contact Agent         Furnished         1  45000
# 527     Contact Agent       Unfurnished         3  75000
# 529     Contact Agent       Unfurnished         1  60000
# 534     Contact Agent    Semi-Furnished         2  33000
# ...               ...               ...       ...    ...
# 1487    Contact Agent       Unfurnished         2  32000
# 1488    Contact Agent    Semi-Furnished         2  78000
# 1490    Contact Agent       Unfurnished         2  45000
# 1491    Contact Agent    Semi-Furnished         2  65000
# 1494    Contact Agent         Furnished         2  90000
#
# [697 rows x 4 columns]

# %%
df_klrg_i_m_ca_f = df_klrg_i_m_ca.loc[df_klrg_i_m['Furnishing Status'] == 'Furnished', ['Bathroom','Rent']]
df_klrg_i_m_ca_f
# Out:
#       Bathroom   Rent
# 525          2  70000
# 526          1  45000
# 535          2  32000
# 555          1  23000
# 564          2  40000
# ...        ...    ...
# 1467         2  90000
# 1469         2  70000
# 1470         2  90000
# 1477         2  45000
# 1494         2  90000
#
# [177 rows x 2 columns]

# %%
df_klrg_i_m_ca_f_2b = df_klrg_i_m_ca_f.loc[df_klrg_i_m['Bathroom'] == 2, ['Rent']]
df_klrg_i_m_ca_f_2b
# Out:
#        Rent
# 525   70000
# 535   32000
# 564   40000
# 566   44000
# 575   55000
# ...     ...
# 1467  90000
# 1469  70000
# 1470  90000
# 1477  45000
# 1494  90000
#
# [91 rows x 1 columns]

# %%
len(df_klrg_i_m_ca_f_2b)
# Out:
# 91

# %% [markdown]
# Hasil:
#
# Data mengenai segmen keluarga inti, Point of Contact memakai agent, Fully Furnished, Carpet Area,
# dengan bathroom 2 pada kota Mumbai adalah 91, yang berarti diatas 50. Tidak benar jika dibawah 50.

# %% [markdown]
# # 5. Pengambilan Kesimpulan

# %% [markdown]
# Dari hasil analisis saya, Saya sudah dapat mengkategorikan masing-masing dari mean dan modenya pada poin 4.1 Eksplorasi Data 2. Dari masing-masing penjabaran pada poin 4.2, saya mendapatkan bahwa rata-rata biaya sewa perbulan untuk segmen Keluarga Inti dan Besar sangatllah berbeda jauh (dari 28,240 untuk Keluarga Inti dan 176,634 untuk Keluarga Besar) sama jauh juga dengan Size (897 untuk Keluarga Inti dan 2,454 untuk Keluarga Besar). Namun dari jumlah Kamar Mandi, hanya berbeda 2 (2 untuk Keluarga Inti dan 4 untuk Keluarga Besar). Kota dengan rata-rata properti tempat tinggal termurah dari Keluarga Inti dan Keluarga Besar sama-sama Kota Kolkata.
#
# Dari hasil uji coba hubungan pada masing-masing variabel, terdapat hubungan pada Tipe Area (Area Type) dan Kontak Informasi lebih lanjut (Point of Contact), Status kelengkapan perabotan (Furnishing Status) dan Tipe Keluarga, Status kelengkapan perabotan (Furnishing Status) dan Preferensi keluarga/bukan keluraga (Tenant Preferred). Status perlengkapan perabotan (Furnishing Status) mempunyai hubungan dengan Tipe Keluarga dan Preferensi keluarga/bukan keluarga (Tenant Preferred)
#
# Perusahaan juga meminta analisis, yang pertama, pada penjabaran 9 dan penjabaran 10, saya mendapati bahwa rentang harga masih jauh (45,000 - 300,000 dan 7,000 - 600,000). Pada penjabaran 11, properti masih diatas dari 50.
